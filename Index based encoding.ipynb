# %%
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords

# %%
#import nltk
#nltk.download('stopwords')

# %%
txt="""A hint of controversy as we wrap up the coverage of the 3rd T20I. Was Rohit declared retired out / retired hurt. If it was the former, he couldn't have come out to bat for the second time, but is there any ambiguity in the game that he could have walked away retired hurt in the first super-over? If so, Rohit has played the rules perfectly. A 212 play 212 in the regular passage of play. A sublime hundred from Rohit after his 2 ducks in the first two games. A record 5th wicket partnership to haul India out of choppy waters at 22 for 4. It was followed by a team batting display as Afghanistan fought hard to drag the match into a super over. Another bit of controversy happened there with Nabi happy to take runs after a deflection off his body, 16 played 16 and we didn't have a winner. A second super over was played and we finally had a winner for the night. Lots of fours, sixes , wickets and an Indian win to savour for the crowd at the Chinnaswamy and we'll leave with only good memories. India now turn their attention towards red-ball cricket and the 5-match Test series against England starts shortly in Hyderabad. Afghanistan will turn attention to the one-off Test against Sri Lanka, starting on February 2nd in Colombo. The cricket season continues with plenty of T20 leagues happening across the world. Do keep watching this space for more exciting action. For now, cheers and bye..

 Rohit collects the trophy and hands it over to Rinku. Jaiswal joins Rinku in lofting the trophy behind the champions hoarding. All smiles in the Indian camp and off they go...

 Rohit Sharma: Player of the Match and Indian skipper: I don't remember when was the last time this happened. I think I batted 3 times in one of the IPL games. Creating the partnership was important and we (Rinku and I) kept talking to each other to not lose that intent in big games and it was a good game for us to be in, the pressure was there and was important to bat long and deep and not compromise on the intent we want to show. The last couple of series that he played, he showed what he can do with the bat. Very calm and knows his strength pretty well. He is coming off age and doing what is expected of him and he has done really well for India. Augurs well for the team moving forward, wanted someone like that at the backend and we know what he has done in the IPL and he has carried that to the Indian colors as well.

 Shivam Dube | Player of the Series - 124 runs and 2 wickets from 3 games: As an all-rounder you always want to be the Player of the Series, and this is something new I achieved in my life and it feels really good. We scored a lot of runs on this ground and we thought we would win before the superover, but such is cricket and well done to both teams. There are many things I want to improve, especially in my bowling and I'm trying to get better with each passing game.

 Ibrahim Zadran | Afghanistan skipper: We are happy with the overall performance. We played good cricket, unfortunately we lost in the superover. We got lots of positives from this series and this experience will help us in the upcoming T20 World Cup. The boys gave their best in these 3 games. We never played this kind of cricket in T20, especially against India and in batting department as well. Really happy. We will take some positives from this series and focus on improving a little bit in the T20 World Cup.

 Ravi Bishnoi: The pressure was there, the heartbeat was racing, but I was confident about getting the job done. I was told by the captain that I'll bowl - I knew it wouldn't be easy for them if I bowl back of the length ball, it would be tough to smash on the back-foot. It gives a lot of pleasure to defend during the super overs. I'm happy with the way the ball is leaving my hand. My only thought is to ensure that the batter doesn't get himself used to only one type of delivery, I've worked on my leg-spin in the nets and at the domestic levels.
"""

# %%
len(txt)
# Out:
# 3955

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
len(stopwords.words('english'))
# Out:
# 179

# %%
#Removing stop words
words=[]
for word in word_tokenize(txt):
    if (word.lower() not in stopwords.words('english') and len(word)>1):
        words.append(word.lower())

# %%
len(words)
# Out:
# 375

# %%
vocab=list(set(words))

# %%
len(vocab)
# Out:
# 259

# %% [markdown]
# ### Creating encoder and decoder

# %%
num=1
word_to_num={}
num_to_word={}
for word in vocab:
    word_to_num[word]=num
    num_to_word[num]=word
    num+=1

# %%
word_to_num
# Out:
# {'gives': 1,
#  'choppy': 2,
#  'bowling': 3,
#  'told': 4,
#  'leave': 5,
#  'action': 6,
#  'tough': 7,
#  'age': 8,
#  'thought': 9,
#  'space': 10,
#  'passing': 11,
#  'lost': 12,
#  'starting': 13,
#  '3rd': 14,
#  'unfortunately': 15,
#  'series': 16,
#  'waters': 17,
#  'wicket': 18,
#  'first': 19,
#  'cheers': 20,
#  'player': 21,
#  'winner': 22,
#  'important': 23,
#  'batted': 24,
#  'someone': 25,
#  'keep': 26,
#  'long': 27,
#  'time': 28,
#  'wickets': 29,
#  'indian': 30,
#  'heartbeat': 31,
#  'game': 32,
#  'something': 33,
#  'attention': 34,
#  'followed': 35,
#  'joins': 36,
#  'display': 37,
#  'show': 38,
#  'good': 39,
#  'starts': 40,
#  'colombo': 41,
#  'india': 42,
#  'test': 43,
#  'super': 44,
#  'lanka': 45,
#  'super-over': 46,
#  'memories': 47,
#  'partnership': 48,
#  'go': 49,
#  'collects': 50,
#  'leaving': 51,
#  'things': 52,
#  'hundred': 53,
#  'behind': 54,
#  'especially': 55,
#  'happening': 56,
#  'hand': 57,
#  'gave': 58,
#  'record': 59,
#  'ibrahim': 60,
#  'lose': 61,
#  'wanted': 62,
#  'match': 63,
#  'lots': 64,
#  'performance': 65,
#  'sixes': 66,
#  'two': 67,
#  'trophy': 68,
#  'remember': 69,
#  'showed': 70,
#  'expected': 71,
#  'cricket': 72,
#  'help': 73,
#  'hint': 74,
#  'dube': 75,
#  'little': 76,
#  'controversy': 77,
#  'body': 78,
#  'coming': 79,
#  'one-off': 80,
#  'lofting': 81,
#  'crowd': 82,
#  "'ve": 83,
#  'many': 84,
#  'leagues': 85,
#  'easy': 86,
#  'england': 87,
#  'afghanistan': 88,
#  'nets': 89,
#  'levels': 90,
#  't20': 91,
#  'rohit': 92,
#  "n't": 93,
#  'sri': 94,
#  'nabi': 95,
#  'superover': 96,
#  'shivam': 97,
#  'another': 98,
#  '..': 99,
#  'red-ball': 100,
#  'life': 101,
#  'continues': 102,
#  'pretty': 103,
#  'games': 104,
#  'ground': 105,
#  'savour': 106,
#  'knows': 107,
#  'augurs': 108,
#  'one': 109,
#  'pressure': 110,
#  'across': 111,
#  'think': 112,
#  'achieved': 113,
#  'leg-spin': 114,
#  'captain': 115,
#  'know': 116,
#  'rules': 117,
#  'win': 118,
#  'jaiswal': 119,
#  'focus': 120,
#  'always': 121,
#  'walked': 122,
#  'best': 123,
#  'improving': 124,
#  'like': 125,
#  'retired': 126,
#  'shortly': 127,
#  'smiles': 128,
#  'camp': 129,
#  'bat': 130,
#  '212': 131,
#  'hyderabad': 132,
#  'champions': 133,
#  'overall': 134,
#  'upcoming': 135,
#  'racing': 136,
#  'knew': 137,
#  'hard': 138,
#  'former': 139,
#  'plenty': 140,
#  'last': 141,
#  'runs': 142,
#  'used': 143,
#  'colors': 144,
#  'smash': 145,
#  'batter': 146,
#  'ducks': 147,
#  'play': 148,
#  'february': 149,
#  'team': 150,
#  'feels': 151,
#  'declared': 152,
#  'worked': 153,
#  'moving': 154,
#  'department': 155,
#  'drag': 156,
#  'talking': 157,
#  'hoarding': 158,
#  'ensure': 159,
#  'regular': 160,
#  "'ll": 161,
#  'boys': 162,
#  'never': 163,
#  'want': 164,
#  '22': 165,
#  'wrap': 166,
#  'rinku': 167,
#  'zadran': 168,
#  'perfectly': 169,
#  'creating': 170,
#  'watching': 171,
#  'well': 172,
#  'would': 173,
#  'big': 174,
#  't20i': 175,
#  'bowl': 176,
#  'bit': 177,
#  'passage': 178,
#  'calm': 179,
#  'teams': 180,
#  'trying': 181,
#  'get': 182,
#  'coverage': 183,
#  'away': 184,
#  'getting': 185,
#  'bye': 186,
#  'ravi': 187,
#  'overs': 188,
#  'back': 189,
#  'done': 190,
#  'happy': 191,
#  'new': 192,
#  'chinnaswamy': 193,
#  'take': 194,
#  'haul': 195,
#  'sharma': 196,
#  'kind': 197,
#  'job': 198,
#  'kept': 199,
#  'could': 200,
#  'compromise': 201,
#  'domestic': 202,
#  'towards': 203,
#  'finally': 204,
#  "'m": 205,
#  'season': 206,
#  'carried': 207,
#  'lot': 208,
#  'hands': 209,
#  'bishnoi': 210,
#  'world': 211,
#  'second': 212,
#  '5th': 213,
#  'fours': 214,
#  'ambiguity': 215,
#  'defend': 216,
#  'sublime': 217,
#  'ipl': 218,
#  'us': 219,
#  'type': 220,
#  'hurt': 221,
#  '...': 222,
#  'all-rounder': 223,
#  'back-foot': 224,
#  'deflection': 225,
#  'confident': 226,
#  'scored': 227,
#  'come': 228,
#  'forward': 229,
#  'ball': 230,
#  'night': 231,
#  '5-match': 232,
#  'times': 233,
#  'strength': 234,
#  'got': 235,
#  '16': 236,
#  'cup': 237,
#  'couple': 238,
#  'fought': 239,
#  'intent': 240,
#  'improve': 241,
#  'better': 242,
#  'way': 243,
#  'exciting': 244,
#  'pleasure': 245,
#  '124': 246,
#  'turn': 247,
#  'happened': 248,
#  'deep': 249,
#  'delivery': 250,
#  'backend': 251,
#  '2nd': 252,
#  'really': 253,
#  'positives': 254,
#  'skipper': 255,
#  'played': 256,
#  'batting': 257,
#  'experience': 258,
#  'length': 259}

# %%
num_to_word[5]
# Out:
# 'leave'

# %% [markdown]
# ### Encoding Sentences

# %%
for sent in sent_tokenize(txt):
    print(sent)
# Out:
# A hint of controversy as we wrap up the coverage of the 3rd T20I.
# Was Rohit declared retired out / retired hurt.
# If it was the former, he couldn't have come out to bat for the second time, but is there any ambiguity in the game that he could have walked away retired hurt in the first super-over?
# If so, Rohit has played the rules perfectly.
# A 212 play 212 in the regular passage of play.
# A sublime hundred from Rohit after his 2 ducks in the first two games.
# A record 5th wicket partnership to haul India out of choppy waters at 22 for 4.
# It was followed by a team batting display as Afghanistan fought hard to drag the match into a super over.
# Another bit of controversy happened there with Nabi happy to take runs after a deflection off his body, 16 played 16 and we didn't have a winner.
# A second super over was played and we finally had a winner for the night.
# Lots of fours, sixes , wickets and an Indian win to savour for the crowd at the Chinnaswamy and we'll leave with only good memories.
# India now turn their attention towards red-ball cricket and the 5-match Test series against England starts shortly in Hyderabad.
# Afghanistan will turn attention to the one-off Test against Sri Lanka, starting on February 2nd in Colombo.
# The cricket season continues with plenty of T20 leagues happening across the world.
# Do keep watching this space for more exciting action.
# For now, cheers and bye..
#
#  Rohit collects the trophy and hands it over to Rinku.
# Jaiswal joins Rinku in lofting the trophy behind the champions hoarding.
# All smiles in the Indian camp and off they go...
#
#  Rohit Sharma: Player of the Match and Indian skipper: I don't remember when was the last time this happened.
# I think I batted 3 times in one of the IPL games.
# Creating the partnership was important and we (Rinku and I) kept talking to each other to not lose that intent in big games and it was a good game for us to be in, the pressure was there and was important to bat long and deep and not compromise on the intent we want to show.
# The last couple of series that he played, he showed what he can do with the bat.
# Very calm and knows his strength pretty well.
# He is coming off age and doing what is expected of him and he has done really well for India.
# Augurs well for the team moving forward, wanted someone like that at the backend and we know what he has done in the IPL and he has carried that to the Indian colors as well.
# Shivam Dube | Player of the Series - 124 runs and 2 wickets from 3 games: As an all-rounder you always want to be the Player of the Series, and this is something new I achieved in my life and it feels really good.
# We scored a lot of runs on this ground and we thought we would win before the superover, but such is cricket and well done to both teams.
# There are many things I want to improve, especially in my bowling and I'm trying to get better with each passing game.
# Ibrahim Zadran | Afghanistan skipper: We are happy with the overall performance.
# We played good cricket, unfortunately we lost in the superover.
# We got lots of positives from this series and this experience will help us in the upcoming T20 World Cup.
# The boys gave their best in these 3 games.
# We never played this kind of cricket in T20, especially against India and in batting department as well.
# Really happy.
# We will take some positives from this series and focus on improving a little bit in the T20 World Cup.
# Ravi Bishnoi: The pressure was there, the heartbeat was racing, but I was confident about getting the job done.
# I was told by the captain that I'll bowl - I knew it wouldn't be easy for them if I bowl back of the length ball, it would be tough to smash on the back-foot.
# It gives a lot of pleasure to defend during the super overs.
# I'm happy with the way the ball is leaving my hand.
# My only thought is to ensure that the batter doesn't get himself used to only one type of delivery, I've worked on my leg-spin in the nets and at the domestic levels.

# %%
for sent in sent_tokenize(txt):
    print(word_tokenize(sent))
# Out:
# ['A', 'hint', 'of', 'controversy', 'as', 'we', 'wrap', 'up', 'the', 'coverage', 'of', 'the', '3rd', 'T20I', '.']
# ['Was', 'Rohit', 'declared', 'retired', 'out', '/', 'retired', 'hurt', '.']
# ['If', 'it', 'was', 'the', 'former', ',', 'he', 'could', "n't", 'have', 'come', 'out', 'to', 'bat', 'for', 'the', 'second', 'time', ',', 'but', 'is', 'there', 'any', 'ambiguity', 'in', 'the', 'game', 'that', 'he', 'could', 'have', 'walked', 'away', 'retired', 'hurt', 'in', 'the', 'first', 'super-over', '?']
# ['If', 'so', ',', 'Rohit', 'has', 'played', 'the', 'rules', 'perfectly', '.']
# ['A', '212', 'play', '212', 'in', 'the', 'regular', 'passage', 'of', 'play', '.']
# ['A', 'sublime', 'hundred', 'from', 'Rohit', 'after', 'his', '2', 'ducks', 'in', 'the', 'first', 'two', 'games', '.']
# ['A', 'record', '5th', 'wicket', 'partnership', 'to', 'haul', 'India', 'out', 'of', 'choppy', 'waters', 'at', '22', 'for', '4', '.']
# ['It', 'was', 'followed', 'by', 'a', 'team', 'batting', 'display', 'as', 'Afghanistan', 'fought', 'hard', 'to', 'drag', 'the', 'match', 'into', 'a', 'super', 'over', '.']
# ['Another', 'bit', 'of', 'controversy', 'happened', 'there', 'with', 'Nabi', 'happy', 'to', 'take', 'runs', 'after', 'a', 'deflection', 'off', 'his', 'body', ',', '16', 'played', '16', 'and', 'we', 'did', "n't", 'have', 'a', 'winner', '.']
# ['A', 'second', 'super', 'over', 'was', 'played', 'and', 'we', 'finally', 'had', 'a', 'winner', 'for', 'the', 'night', '.']
# ['Lots', 'of', 'fours', ',', 'sixes', ',', 'wickets', 'and', 'an', 'Indian', 'win', 'to', 'savour', 'for', 'the', 'crowd', 'at', 'the', 'Chinnaswamy', 'and', 'we', "'ll", 'leave', 'with', 'only', 'good', 'memories', '.']
# ['India', 'now', 'turn', 'their', 'attention', 'towards', 'red-ball', 'cricket', 'and', 'the', '5-match', 'Test', 'series', 'against', 'England', 'starts', 'shortly', 'in', 'Hyderabad', '.']
# ['Afghanistan', 'will', 'turn', 'attention', 'to', 'the', 'one-off', 'Test', 'against', 'Sri', 'Lanka', ',', 'starting', 'on', 'February', '2nd', 'in', 'Colombo', '.']
# ['The', 'cricket', 'season', 'continues', 'with', 'plenty', 'of', 'T20', 'leagues', 'happening', 'across', 'the', 'world', '.']
# ['Do', 'keep', 'watching', 'this', 'space', 'for', 'more', 'exciting', 'action', '.']
# ['For', 'now', ',', 'cheers', 'and', 'bye', '..', 'Rohit', 'collects', 'the', 'trophy', 'and', 'hands', 'it', 'over', 'to', 'Rinku', '.']
# ['Jaiswal', 'joins', 'Rinku', 'in', 'lofting', 'the', 'trophy', 'behind', 'the', 'champions', 'hoarding', '.']
# ['All', 'smiles', 'in', 'the', 'Indian', 'camp', 'and', 'off', 'they', 'go', '...', 'Rohit', 'Sharma', ':', 'Player', 'of', 'the', 'Match', 'and', 'Indian', 'skipper', ':', 'I', 'do', "n't", 'remember', 'when', 'was', 'the', 'last', 'time', 'this', 'happened', '.']
# ['I', 'think', 'I', 'batted', '3', 'times', 'in', 'one', 'of', 'the', 'IPL', 'games', '.']
# ['Creating', 'the', 'partnership', 'was', 'important', 'and', 'we', '(', 'Rinku', 'and', 'I', ')', 'kept', 'talking', 'to', 'each', 'other', 'to', 'not', 'lose', 'that', 'intent', 'in', 'big', 'games', 'and', 'it', 'was', 'a', 'good', 'game', 'for', 'us', 'to', 'be', 'in', ',', 'the', 'pressure', 'was', 'there', 'and', 'was', 'important', 'to', 'bat', 'long', 'and', 'deep', 'and', 'not', 'compromise', 'on', 'the', 'intent', 'we', 'want', 'to', 'show', '.']
# ['The', 'last', 'couple', 'of', 'series', 'that', 'he', 'played', ',', 'he', 'showed', 'what', 'he', 'can', 'do', 'with', 'the', 'bat', '.']
# ['Very', 'calm', 'and', 'knows', 'his', 'strength', 'pretty', 'well', '.']
# ['He', 'is', 'coming', 'off', 'age', 'and', 'doing', 'what', 'is', 'expected', 'of', 'him', 'and', 'he', 'has', 'done', 'really', 'well', 'for', 'India', '.']
# ['Augurs', 'well', 'for', 'the', 'team', 'moving', 'forward', ',', 'wanted', 'someone', 'like', 'that', 'at', 'the', 'backend', 'and', 'we', 'know', 'what', 'he', 'has', 'done', 'in', 'the', 'IPL', 'and', 'he', 'has', 'carried', 'that', 'to', 'the', 'Indian', 'colors', 'as', 'well', '.']
# ['Shivam', 'Dube', '|', 'Player', 'of', 'the', 'Series', '-', '124', 'runs', 'and', '2', 'wickets', 'from', '3', 'games', ':', 'As', 'an', 'all-rounder', 'you', 'always', 'want', 'to', 'be', 'the', 'Player', 'of', 'the', 'Series', ',', 'and', 'this', 'is', 'something', 'new', 'I', 'achieved', 'in', 'my', 'life', 'and', 'it', 'feels', 'really', 'good', '.']
# ['We', 'scored', 'a', 'lot', 'of', 'runs', 'on', 'this', 'ground', 'and', 'we', 'thought', 'we', 'would', 'win', 'before', 'the', 'superover', ',', 'but', 'such', 'is', 'cricket', 'and', 'well', 'done', 'to', 'both', 'teams', '.']
# ['There', 'are', 'many', 'things', 'I', 'want', 'to', 'improve', ',', 'especially', 'in', 'my', 'bowling', 'and', 'I', "'m", 'trying', 'to', 'get', 'better', 'with', 'each', 'passing', 'game', '.']
# ['Ibrahim', 'Zadran', '|', 'Afghanistan', 'skipper', ':', 'We', 'are', 'happy', 'with', 'the', 'overall', 'performance', '.']
# ['We', 'played', 'good', 'cricket', ',', 'unfortunately', 'we', 'lost', 'in', 'the', 'superover', '.']
# ['We', 'got', 'lots', 'of', 'positives', 'from', 'this', 'series', 'and', 'this', 'experience', 'will', 'help', 'us', 'in', 'the', 'upcoming', 'T20', 'World', 'Cup', '.']
# ['The', 'boys', 'gave', 'their', 'best', 'in', 'these', '3', 'games', '.']
# ['We', 'never', 'played', 'this', 'kind', 'of', 'cricket', 'in', 'T20', ',', 'especially', 'against', 'India', 'and', 'in', 'batting', 'department', 'as', 'well', '.']
# ['Really', 'happy', '.']
# ['We', 'will', 'take', 'some', 'positives', 'from', 'this', 'series', 'and', 'focus', 'on', 'improving', 'a', 'little', 'bit', 'in', 'the', 'T20', 'World', 'Cup', '.']
# ['Ravi', 'Bishnoi', ':', 'The', 'pressure', 'was', 'there', ',', 'the', 'heartbeat', 'was', 'racing', ',', 'but', 'I', 'was', 'confident', 'about', 'getting', 'the', 'job', 'done', '.']
# ['I', 'was', 'told', 'by', 'the', 'captain', 'that', 'I', "'ll", 'bowl', '-', 'I', 'knew', 'it', 'would', "n't", 'be', 'easy', 'for', 'them', 'if', 'I', 'bowl', 'back', 'of', 'the', 'length', 'ball', ',', 'it', 'would', 'be', 'tough', 'to', 'smash', 'on', 'the', 'back-foot', '.']
# ['It', 'gives', 'a', 'lot', 'of', 'pleasure', 'to', 'defend', 'during', 'the', 'super', 'overs', '.']
# ['I', "'m", 'happy', 'with', 'the', 'way', 'the', 'ball', 'is', 'leaving', 'my', 'hand', '.']
# ['My', 'only', 'thought', 'is', 'to', 'ensure', 'that', 'the', 'batter', 'does', "n't", 'get', 'himself', 'used', 'to', 'only', 'one', 'type', 'of', 'delivery', ',', 'I', "'ve", 'worked', 'on', 'my', 'leg-spin', 'in', 'the', 'nets', 'and', 'at', 'the', 'domestic', 'levels', '.']

# %%
sentence_num=[]
for sent in sent_tokenize(txt):
    words_=[]
    words_num=[]
    
    for word in word_tokenize(sent):
        if (word.lower() not in stopwords.words('english') and len(word)>1):
            words_.append(word.lower())
            #print(word,end=' ')
            #print(word_to_num[word.lower()],end=' ')
            words_num.append(word_to_num[word.lower()])
    print(words_)
    sentence_num.append(words_num)
    print(words_num)
# Out:
# ['hint', 'controversy', 'wrap', 'coverage', '3rd', 't20i']
# [74, 77, 166, 183, 14, 175]
# ['rohit', 'declared', 'retired', 'retired', 'hurt']
# [92, 152, 126, 126, 221]
# ['former', 'could', "n't", 'come', 'bat', 'second', 'time', 'ambiguity', 'game', 'could', 'walked', 'away', 'retired', 'hurt', 'first', 'super-over']
# [139, 200, 93, 228, 130, 212, 28, 215, 32, 200, 122, 184, 126, 221, 19, 46]
# ['rohit', 'played', 'rules', 'perfectly']
# [92, 256, 117, 169]
# ['212', 'play', '212', 'regular', 'passage', 'play']
# [131, 148, 131, 160, 178, 148]
# ['sublime', 'hundred', 'rohit', 'ducks', 'first', 'two', 'games']
# [217, 53, 92, 147, 19, 67, 104]
# ['record', '5th', 'wicket', 'partnership', 'haul', 'india', 'choppy', 'waters', '22']
# [59, 213, 18, 48, 195, 42, 2, 17, 165]
# ['followed', 'team', 'batting', 'display', 'afghanistan', 'fought', 'hard', 'drag', 'match', 'super']
# [35, 150, 257, 37, 88, 239, 138, 156, 63, 44]
# ['another', 'bit', 'controversy', 'happened', 'nabi', 'happy', 'take', 'runs', 'deflection', 'body', '16', 'played', '16', "n't", 'winner']
# [98, 177, 77, 248, 95, 191, 194, 142, 225, 78, 236, 256, 236, 93, 22]
# ['second', 'super', 'played', 'finally', 'winner', 'night']
# [212, 44, 256, 204, 22, 231]
# ['lots', 'fours', 'sixes', 'wickets', 'indian', 'win', 'savour', 'crowd', 'chinnaswamy', "'ll", 'leave', 'good', 'memories']
# [64, 214, 66, 29, 30, 118, 106, 82, 193, 161, 5, 39, 47]
# ['india', 'turn', 'attention', 'towards', 'red-ball', 'cricket', '5-match', 'test', 'series', 'england', 'starts', 'shortly', 'hyderabad']
# [42, 247, 34, 203, 100, 72, 232, 43, 16, 87, 40, 127, 132]
# ['afghanistan', 'turn', 'attention', 'one-off', 'test', 'sri', 'lanka', 'starting', 'february', '2nd', 'colombo']
# [88, 247, 34, 80, 43, 94, 45, 13, 149, 252, 41]
# ['cricket', 'season', 'continues', 'plenty', 't20', 'leagues', 'happening', 'across', 'world']
# [72, 206, 102, 140, 91, 85, 56, 111, 211]
# ['keep', 'watching', 'space', 'exciting', 'action']
# [26, 171, 10, 244, 6]
# ['cheers', 'bye', '..', 'rohit', 'collects', 'trophy', 'hands', 'rinku']
# [20, 186, 99, 92, 50, 68, 209, 167]
# ['jaiswal', 'joins', 'rinku', 'lofting', 'trophy', 'behind', 'champions', 'hoarding']
# [119, 36, 167, 81, 68, 54, 133, 158]
# ['smiles', 'indian', 'camp', 'go', '...', 'rohit', 'sharma', 'player', 'match', 'indian', 'skipper', "n't", 'remember', 'last', 'time', 'happened']
# [128, 30, 129, 49, 222, 92, 196, 21, 63, 30, 255, 93, 69, 141, 28, 248]
# ['think', 'batted', 'times', 'one', 'ipl', 'games']
# [112, 24, 233, 109, 218, 104]
# ['creating', 'partnership', 'important', 'rinku', 'kept', 'talking', 'lose', 'intent', 'big', 'games', 'good', 'game', 'us', 'pressure', 'important', 'bat', 'long', 'deep', 'compromise', 'intent', 'want', 'show']
# [170, 48, 23, 167, 199, 157, 61, 240, 174, 104, 39, 32, 219, 110, 23, 130, 27, 249, 201, 240, 164, 38]
# ['last', 'couple', 'series', 'played', 'showed', 'bat']
# [141, 238, 16, 256, 70, 130]
# ['calm', 'knows', 'strength', 'pretty', 'well']
# [179, 107, 234, 103, 172]
# ['coming', 'age', 'expected', 'done', 'really', 'well', 'india']
# [79, 8, 71, 190, 253, 172, 42]
# ['augurs', 'well', 'team', 'moving', 'forward', 'wanted', 'someone', 'like', 'backend', 'know', 'done', 'ipl', 'carried', 'indian', 'colors', 'well']
# [108, 172, 150, 154, 229, 62, 25, 125, 251, 116, 190, 218, 207, 30, 144, 172]
# ['shivam', 'dube', 'player', 'series', '124', 'runs', 'wickets', 'games', 'all-rounder', 'always', 'want', 'player', 'series', 'something', 'new', 'achieved', 'life', 'feels', 'really', 'good']
# [97, 75, 21, 16, 246, 142, 29, 104, 223, 121, 164, 21, 16, 33, 192, 113, 101, 151, 253, 39]
# ['scored', 'lot', 'runs', 'ground', 'thought', 'would', 'win', 'superover', 'cricket', 'well', 'done', 'teams']
# [227, 208, 142, 105, 9, 173, 118, 96, 72, 172, 190, 180]
# ['many', 'things', 'want', 'improve', 'especially', 'bowling', "'m", 'trying', 'get', 'better', 'passing', 'game']
# [84, 52, 164, 241, 55, 3, 205, 181, 182, 242, 11, 32]
# ['ibrahim', 'zadran', 'afghanistan', 'skipper', 'happy', 'overall', 'performance']
# [60, 168, 88, 255, 191, 134, 65]
# ['played', 'good', 'cricket', 'unfortunately', 'lost', 'superover']
# [256, 39, 72, 15, 12, 96]
# ['got', 'lots', 'positives', 'series', 'experience', 'help', 'us', 'upcoming', 't20', 'world', 'cup']
# [235, 64, 254, 16, 258, 73, 219, 135, 91, 211, 237]
# ['boys', 'gave', 'best', 'games']
# [162, 58, 123, 104]
# ['never', 'played', 'kind', 'cricket', 't20', 'especially', 'india', 'batting', 'department', 'well']
# [163, 256, 197, 72, 91, 55, 42, 257, 155, 172]
# ['really', 'happy']
# [253, 191]
# ['take', 'positives', 'series', 'focus', 'improving', 'little', 'bit', 't20', 'world', 'cup']
# [194, 254, 16, 120, 124, 76, 177, 91, 211, 237]
# ['ravi', 'bishnoi', 'pressure', 'heartbeat', 'racing', 'confident', 'getting', 'job', 'done']
# [187, 210, 110, 31, 136, 226, 185, 198, 190]
# ['told', 'captain', "'ll", 'bowl', 'knew', 'would', "n't", 'easy', 'bowl', 'back', 'length', 'ball', 'would', 'tough', 'smash', 'back-foot']
# [4, 115, 161, 176, 137, 173, 93, 86, 176, 189, 259, 230, 173, 7, 145, 224]
# ['gives', 'lot', 'pleasure', 'defend', 'super', 'overs']
# [1, 208, 245, 216, 44, 188]
# ["'m", 'happy', 'way', 'ball', 'leaving', 'hand']
# [205, 191, 243, 230, 51, 57]
# ['thought', 'ensure', 'batter', "n't", 'get', 'used', 'one', 'type', 'delivery', "'ve", 'worked', 'leg-spin', 'nets', 'domestic', 'levels']
# [9, 159, 146, 93, 182, 143, 109, 220, 250, 83, 153, 114, 89, 202, 90]

# %% [markdown]
# ### Decoding Sentences

# %%
for sent in sentence_num:
    for word in sent:
        print(num_to_word[word],end=' ')
    print()
# Out:
# hint controversy wrap coverage 3rd t20i
# rohit declared retired retired hurt
# former could n't come bat second time ambiguity game could walked away retired hurt first super-over
# rohit played rules perfectly
# 212 play 212 regular passage play
# sublime hundred rohit ducks first two games
# record 5th wicket partnership haul india choppy waters 22
# followed team batting display afghanistan fought hard drag match super
# another bit controversy happened nabi happy take runs deflection body 16 played 16 n't winner
# second super played finally winner night
# lots fours sixes wickets indian win savour crowd chinnaswamy 'll leave good memories
# india turn attention towards red-ball cricket 5-match test series england starts shortly hyderabad
# afghanistan turn attention one-off test sri lanka starting february 2nd colombo
# cricket season continues plenty t20 leagues happening across world
# keep watching space exciting action
# cheers bye .. rohit collects trophy hands rinku
# jaiswal joins rinku lofting trophy behind champions hoarding
# smiles indian camp go ... rohit sharma player match indian skipper n't remember last time happened
# think batted times one ipl games
# creating partnership important rinku kept talking lose intent big games good game us pressure important bat long deep compromise intent want show
# last couple series played showed bat
# calm knows strength pretty well
# coming age expected done really well india
# augurs well team moving forward wanted someone like backend know done ipl carried indian colors well
# shivam dube player series 124 runs wickets games all-rounder always want player series something new achieved life feels really good
# scored lot runs ground thought would win superover cricket well done teams
# many things want improve especially bowling 'm trying get better passing game
# ibrahim zadran afghanistan skipper happy overall performance
# played good cricket unfortunately lost superover
# got lots positives series experience help us upcoming t20 world cup
# boys gave best games
# never played kind cricket t20 especially india batting department well
# really happy
# take positives series focus improving little bit t20 world cup
# ravi bishnoi pressure heartbeat racing confident getting job done
# told captain 'll bowl knew would n't easy bowl back length ball would tough smash back-foot
# gives lot pleasure defend super overs
# 'm happy way ball leaving hand
# thought ensure batter n't get used one type delivery 've worked leg-spin nets domestic levels
